# %% [markdown]
# <a href="https://colab.research.google.com/github/clobos/Python_Gemini_Colab/blob/main/Roseli_a_minha_amiga.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Amiga Roseli, como você está hoje?
#
# Você já tomou seu vinho chileno ou sua cervejinha?

# %%
import pandas as pd
